# %%
#%%
from astrocalc.keplerian_ui import OrbitalMechanicsWidget
from astrocalc.equations.keplerian_equations import KeplerianEquations
from astrocalc.util.equation_helpers import create_equation_renderers, EquationGroup, render_equation_groups

import ipywidgets as widgets
from IPython.display import display, HTML

display(HTML("<style>.container { width:95% !important; }</style>"))

orbital = KeplerianEquations()

equation_groups = [
    EquationGroup("General Orbital Equations", [
        orbital.vis_viva(),
        orbital.mean_motion(),
        orbital.orbital_period(),
        orbital.semi_latus_rectum(),
        orbital.velocity_elliptical(),
    ]),
    EquationGroup("Circular Orbit Equations", [
        orbital.circular_velocity(),
    ]),
    EquationGroup("Parabolic Equations", [
        orbital.escape_velocity(),
    ]),
]

equation_renderers = create_equation_renderers(equation_groups)
elements_widget = OrbitalMechanicsWidget(orbital, equation_renderers)

def evaluate_all_equations(_b=None):
    elements_widget.evaluate_and_display()

elements_widget.evaluate_button.on_click(evaluate_all_equations)

# Initial evaluation
elements_widget.evaluate_and_display()

display(
    widgets.HTML("<h3>Orbital Elements</h3>"),
    elements_widget.unit_selectors,
    *elements_widget.get_field_container_list(),
    elements_widget.evaluate_button,
    widgets.HTML("<h3>Equations</h3>"),
    render_equation_groups(equation_groups, equation_renderers),
)
# Out:
# <style>.container { width:95% !important; }</style>
# HTML(value='<h3>Orbital Elements</h3>')
# HBox(children=(Dropdown(description='Length Unit:', index=1, options=(('meter', <SimpleUnit meter (m) ×1>), ('…
# HBox(children=(FloatText(value=7000.0, description='a (semi-major axis):'), HTML(value='km', layout=Layout(wid…
# HBox(children=(FloatText(value=0.001, description='e (eccentricity):'), HTML(value='1', layout=Layout(width='8…
# HBox(children=(FloatText(value=0.1, description='i (inclination):'), HTML(value='deg', layout=Layout(width='80…
# HBox(children=(FloatText(value=1.0, description='RAAN:'), HTML(value='deg', layout=Layout(width='80px'))))
# HBox(children=(FloatText(value=0.5, description='Arg of Periapsis:'), HTML(value='deg', layout=Layout(width='8…
# HBox(children=(FloatText(value=0.0, description='True Anomaly:'), HTML(value='deg', layout=Layout(width='80px'…
# HBox(children=(FloatText(value=398600.0, description='μ (GM):'), HTML(value='km³/s²', layout=Layout(width='80p…
# Button(button_style='primary', description='Evaluate Elements', style=ButtonStyle())
# HTML(value='<h3>Equations</h3>')
# VBox(children=(VBox(children=(HTML(value="<h3 style='margin-top:10px'>General Orbital Equations</h3>"), GridBo…
